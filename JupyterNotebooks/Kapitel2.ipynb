# %% [markdown]
# # Kapitel 2

# %%
3*5
# Out:
# 15

# %%
123-5678
# Out:
# -5555

# %%
18/5
# Out:
# 3.6

# %%
18//5
# Out:
# 3

# %%
18%5
# Out:
# 3

# %%
5**3
# Out:
# 125

# %%
int(3.7) # Das rundet immer ab
# Out:
# 3

# %%
round(3.7)
# Out:
# 4

# %%
a=122.5
b=791
A=a*b
U=2*a+2*b
print(A)
U
# Out:
# 96897.5
# 1827.0

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# A          float    96897.5
# U          float    1827.0
# a          float    122.5
# b          int      791

# %%
type(b)
# Out:
# int

# %%
import math
math.sqrt(4)
# Out:
# 2.0

# %%
math.sin(1)
# Out:
# 0.8414709848078965

# %%
math.acos(-1)
# Out:
# 3.141592653589793

# %%
for x in range(1,10): 
    print(x, x**2 + 3*x + 5)
# Out:
# 1 9
# 2 15
# 3 23
# 4 33
# 5 45
# 6 59
# 7 75
# 8 93
# 9 113

# %%
for x in range(1,10): 
    print("f(",x,")=", x**2 + 3*x + 5)
# Out:
# f( 1 )= 9
# f( 2 )= 15
# f( 3 )= 23
# f( 4 )= 33
# f( 5 )= 45
# f( 6 )= 59
# f( 7 )= 75
# f( 8 )= 93
# f( 9 )= 113

# %%
s=0; n=100 
for i in range(1,n+1):  
    s=s+i
s
# Out:
# 5050

# %%
counter=0
for i in range(1,101):
    if not(i%14==0): 
        counter=counter+1
counter
# Out:
# 93

# %%
sp # Das gibt eine Fehlermeldung, weil sp nicht definiert ist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 sp # Das gibt eine Fehlermeldung, weil sp nicht definiert ist
#
# NameError: name 'sp' is not defined
